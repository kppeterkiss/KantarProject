# %%
import psycopg2

# %%
conn_details = psycopg2.connect(
   host="localhost",
   database="postgres",
   user="postgres",
   password="example",
   port= '5432'
)

# %%
# import packages 
import psycopg2 
import pandas as pd 
from sqlalchemy import create_engine 
  
# establish connections 
conn_string = 'postgresql://postgres:example@127.0.0.1/postgres'
  
db = create_engine(conn_string) 
conn = db.connect() 
conn1 = psycopg2.connect( 
    database="postgres", 
    user='postgres',  
    password='example',  
    host='127.0.0.1',  
    port= '5432'
) 
  
conn1.autocommit = True
cursor = conn1.cursor() 
  
# drop table if it already exists 
cursor.execute('drop table if exists airlines_final') 
  
sql = '''CREATE TABLE airlines_final(id int , 
day int ,airline char(20),destination char(20));'''
  
cursor.execute(sql) 
  
# import the csv file to create a dataframe 
data = pd.read_csv("airlines_final.csv") 
  
data = data[["id","day","airline","destination"]] 
# Create DataFrame 
print(data) 
  
# converting data to sql 
data.to_sql('airlines_final', conn, if_exists= 'replace',method = 'multi') 
  
# fetching all rows 
sql1='''select * from airlines_final;'''
cursor.execute(sql1) 
for i in cursor.fetchall(): 
    print(i) 
  
conn1.commit() 
conn1.close()
# Out:
#         id        day        airline        destination
# 0     1351    Tuesday    UNITED INTL             KANSAI
# 1      373     Friday         ALASKA  SAN JOSE DEL CABO
# 2     2820   Thursday          DELTA        LOS ANGELES
# 3     1157    Tuesday      SOUTHWEST        LOS ANGELES
# 4     2992  Wednesday       AMERICAN              MIAMI
# ...    ...        ...            ...                ...
# 2804  1475    Tuesday         ALASKA       NEW YORK-JFK
# 2805  2222   Thursday      SOUTHWEST            PHOENIX
# 2806  2684     Friday         UNITED            ORLANDO
# 2807  2549    Tuesday        JETBLUE         LONG BEACH
# 2808  2162   Saturday  CHINA EASTERN            QINGDAO
#
# [2477 rows x 4 columns]
# (0, 1351, 'Tuesday', 'UNITED INTL', 'KANSAI')
# (1, 373, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (2, 2820, 'Thursday', 'DELTA', 'LOS ANGELES')
# (3, 1157, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (4, 2992, 'Wednesday', 'AMERICAN', 'MIAMI')
# (5, 634, 'Thursday', 'ALASKA', 'NEWARK')
# (6, 2578, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (8, 2592, 'Saturday', 'AEROMEXICO', 'MEXICO CITY')
# (9, 919, 'Friday', 'AIR CANADA', 'TORONTO')
# (10, 3028, 'Tuesday', 'UNITED', 'PORTLAND')
# (11, 1129, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (12, 2648, 'Saturday', 'JETBLUE', 'BOSTON')
# (13, 3104, 'Tuesday', 'UNITED', 'SPOKANE')
# (14, 2589, 'Saturday', 'INTERJET', 'GUADALAJARA')
# (15, 2345, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (16, 390, 'Friday', 'ALASKA', 'LOS ANGELES')
# (17, 954, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (18, 2913, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (19, 803, 'Sunday', 'ALASKA', 'BALTIMORE')
# (20, 767, 'Thursday', 'AIR CANADA', 'TORONTO')
# (21, 1214, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (22, 1373, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (23, 1263, 'Thursday', 'UNITED INTL', 'TOKYO-NARITA')
# (24, 2723, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (25, 3097, 'Tuesday', 'UNITED', 'SPOKANE')
# (27, 214, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (28, 1372, 'Tuesday', 'UNITED INTL', 'PARIS-DE GAULLE')
# (29, 1956, 'Tuesday', 'UNITED', 'BOSTON')
# (30, 1716, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (31, 1487, 'Wednesday', 'HAWAIIAN AIR', 'HONOLULU')
# (32, 842, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (33, 930, 'Friday', 'AIR CANADA', 'TORONTO')
# (34, 3064, 'Sunday', 'COPA', 'PANAMA CITY')
# (35, 743, 'Sunday', 'ALASKA', 'NEW YORK-JFK')
# (36, 2099, 'Monday', 'UNITED INTL', 'MEXICO CITY')
# (37, 315, 'Thursday', 'UNITED', 'SAN DIEGO')
# (38, 2216, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (39, 3121, 'Sunday', 'ALASKA', 'NEWARK')
# (41, 2890, 'Sunday', 'WOW', 'REYKJAVIK')
# (42, 3046, 'Tuesday', 'AMERICAN', 'LOS ANGELES')
# (43, 3183, 'Thursday', 'DELTA', 'LOS ANGELES')
# (44, 2288, 'Tuesday', 'UNITED', 'SAN ANTONIO')
# (45, 2740, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (46, 1570, 'Wednesday', 'UNITED INTL', 'HONG KONG')
# (47, 3228, 'Thursday', 'ALASKA', 'PORTLAND')
# (48, 1140, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (49, 349, 'Friday', 'ALASKA', 'SAN DIEGO')
# (50, 1572, 'Wednesday', 'UNITED INTL', 'HONG KONG')
# (52, 1635, 'Thursday', 'KOREAN AIR', 'SEOUL')
# (56, 524, 'Thursday', 'EMIRATES', 'DUBAI')
# (57, 1139, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (58, 314, 'Thursday', 'UNITED', 'SAN DIEGO')
# (59, 558, 'Thursday', 'EMIRATES', 'DUBAI')
# (60, 262, 'Friday', 'AIR CANADA', 'TORONTO')
# (61, 2537, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (62, 1713, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (63, 407, 'Saturday', 'UNITED', 'PHOENIX')
# (64, 3212, 'Thursday', 'AMERICAN', 'LOS ANGELES')
# (65, 450, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (66, 1477, 'Wednesday', 'AVIANCA', 'SAN SALVADOR')
# (67, 3151, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (68, 2257, 'Wednesday', 'UNITED', 'LOS ANGELES')
# (69, 2400, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (70, 2230, 'Wednesday', 'AER LINGUS', 'DUBLIN')
# (71, 2865, 'Wednesday', 'UNITED', 'WASHINGTON DC-DULLES')
# (72, 387, 'Friday', 'ALASKA', 'INDIANAPOLIS')
# (73, 1957, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (74, 2526, 'Tuesday', 'JETBLUE', 'LONG BEACH')
# (75, 3041, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (76, 813, 'Sunday', 'ALASKA', 'PORTLAND')
# (77, 1523, 'Wednesday', 'JETBLUE', 'NEW YORK-JFK')
# (78, 2796, 'Sunday', 'WOW', 'REYKJAVIK')
# (79, 3255, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (80, 2042, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (81, 3062, 'Sunday', 'PHILIPPINE AIRLINES', 'MANILA')
# (82, 2026, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (83, 1793, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (84, 1366, 'Tuesday', 'UNITED INTL', 'KANSAI')
# (85, 1017, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (86, 2501, 'Friday', 'ALASKA', 'SALT LAKE CITY')
# (88, 3202, 'Sunday', 'CATHAY PACIFIC', 'HONG KONG')
# (89, 1747, 'Monday', 'LUFTHANSA', 'MUNICH')
# (90, 1954, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (91, 643, 'Thursday', 'ALASKA', 'NEW ORLEANS')
# (93, 2258, 'Wednesday', 'WOW', 'REYKJAVIK')
# (94, 2334, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (95, 1887, 'Tuesday', 'UNITED', 'BOSTON')
# (97, 363, 'Friday', 'LUFTHANSA', 'FRANKFURT')
# (99, 2443, 'Tuesday', 'JETBLUE', 'BOSTON')
# (100, 2321, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (101, 1593, 'Thursday', 'SOUTHWEST', 'LOS ANGELES')
# (103, 716, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (104, 2320, 'Wednesday', 'QANTAS', 'SYDNEY')
# (106, 2038, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (107, 550, 'Thursday', 'EMIRATES', 'DUBAI')
# (108, 746, 'Sunday', 'ALASKA', 'NEW YORK-JFK')
# (109, 2739, 'Friday', 'UNITED', 'KAHULUI')
# (110, 1984, 'Friday', 'AIR FRANCE/KLM', 'AMSTERDAM')
# (111, 2566, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (112, 2200, 'Wednesday', 'AER LINGUS', 'DUBLIN')
# (113, 340, 'Wednesday', 'SOUTHWEST', 'PHOENIX')
# (114, 1252, 'Thursday', 'UNITED INTL', 'TOKYO-NARITA')
# (115, 1946, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (116, 2627, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (117, 1563, 'Wednesday', 'DELTA', 'ATLANTA')
# (118, 752, 'Thursday', 'AIR CANADA', 'TORONTO')
# (120, 3135, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (121, 1123, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (122, 2220, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (123, 3065, 'Tuesday', 'UNITED', 'SPOKANE')
# (124, 3052, 'Tuesday', 'AMERICAN', 'MIAMI')
# (125, 2847, 'Tuesday', 'UNITED', 'SEATTLE')
# (127, 884, 'Tuesday', 'ALASKA', 'SEATTLE')
# (128, 2054, 'Friday', 'UNITED', 'NEWARK')
# (129, 1571, 'Wednesday', 'DELTA', 'DETROIT')
# (130, 747, 'Sunday', 'ALASKA', 'NEW YORK-JFK')
# (132, 1799, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (134, 2281, 'Wednesday', 'QANTAS', 'SYDNEY')
# (135, 2711, 'Friday', 'UNITED', 'SANTA BARBARA')
# (136, 917, 'Friday', 'AIR CANADA', 'TORONTO')
# (137, 2091, 'Thursday', 'AMERICAN', 'PHILADELPHIA')
# (139, 265, 'Friday', 'AIR CANADA', 'TORONTO')
# (140, 2387, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (141, 3254, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (142, 772, 'Thursday', 'UNITED INTL', 'SAN JOSE DEL CABO')
# (143, 465, 'Sunday', 'UNITED', 'DENVER')
# (144, 374, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (145, 367, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (146, 2113, 'Friday', 'JETBLUE', 'LONG BEACH')
# (148, 1970, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (149, 1012, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (150, 1739, 'Monday', 'AIR CANADA', 'TORONTO')
# (151, 2004, 'Wednesday', 'UNITED', 'NEWARK')
# (152, 2016, 'Wednesday', 'UNITED', 'NEWARK')
# (153, 2262, 'Saturday', 'UNITED', 'BAKERSFIELD')
# (154, 2482, 'Friday', 'ALASKA', 'SALT LAKE CITY')
# (155, 2969, 'Tuesday', 'UNITED', 'HONOLULU')
# (156, 2575, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (157, 637, 'Thursday', 'ALASKA', 'NEW ORLEANS')
# (158, 2497, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (160, 1724, 'Monday', 'AIR CANADA', 'TORONTO')
# (161, 805, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (162, 3169, 'Thursday', 'DELTA', 'LOS ANGELES')
# (163, 1090, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (164, 270, 'Thursday', 'UNITED', 'LOS ANGELES')
# (165, 569, 'Thursday', 'ALASKA', 'SEATTLE')
# (166, 2319, 'Wednesday', 'QANTAS', 'SYDNEY')
# (167, 3223, 'Thursday', 'AMERICAN', 'LOS ANGELES')
# (168, 2922, 'Thursday', 'DELTA', 'SEATTLE')
# (169, 13, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (170, 1719, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (171, 3186, 'Thursday', 'DELTA', 'LOS ANGELES')
# (172, 2157, 'Wednesday', 'FRONTIER', 'DENVER')
# (173, 1103, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (174, 2053, 'Friday', 'UNITED', 'NEWARK')
# (175, 2353, 'Wednesday', 'UNITED', 'AUSTIN')
# (176, 3048, 'Sunday', 'PHILIPPINE AIRLINES', 'MANILA')
# (177, 2143, 'Wednesday', 'FRONTIER', 'DENVER')
# (178, 1113, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (180, 1303, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (181, 1261, 'Thursday', 'CHINA EASTERN', 'SHANGHAI')
# (182, 9004, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (183, 1913, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (184, 3035, 'Tuesday', 'UNITED', 'PORTLAND')
# (185, 1542, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (186, 2352, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (187, 801, 'Sunday', 'ALASKA', 'BALTIMORE')
# (189, 529, 'Thursday', 'EMIRATES', 'DUBAI')
# (191, 3107, 'Tuesday', 'UNITED', 'SPOKANE')
# (192, 1785, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (193, 202, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (194, 883, 'Tuesday', 'ALASKA', 'SEATTLE')
# (195, 3142, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (196, 3157, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (197, 1894, 'Monday', 'LUFTHANSA', 'MUNICH')
# (198, 458, 'Sunday', 'UNITED', 'DALLAS-FT. WORTH')
# (199, 2020, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (200, 312, 'Thursday', 'UNITED', 'SAN DIEGO')
# (201, 2903, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (202, 2108, 'Friday', 'JETBLUE', 'LONG BEACH')
# (203, 339, 'Wednesday', 'SOUTHWEST', 'PHOENIX')
# (204, 2938, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (205, 1396, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (206, 1843, 'Wednesday', 'SOUTHWEST', 'SAN DIEGO')
# (207, 3038, 'Tuesday', 'UNITED', 'PORTLAND')
# (208, 1482, 'Wednesday', 'FRONTIER', 'DENVER')
# (209, 2670, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (211, 756, 'Sunday', 'ALASKA', 'NEW YORK-JFK')
# (212, 2128, 'Wednesday', 'FRONTIER', 'DENVER')
# (213, 1514, 'Wednesday', 'INTERJET', 'GUADALAJARA')
# (215, 2481, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (217, 1150, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (218, 1105, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (219, 2945, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (220, 261, 'Friday', 'AIR CANADA', 'TORONTO')
# (221, 819, 'Sunday', 'ALASKA', 'PORTLAND')
# (223, 2924, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (224, 2245, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (225, 238, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (226, 1077, 'Friday', 'AIR CANADA', 'CALGARY')
# (227, 3176, 'Thursday', 'DELTA', 'LOS ANGELES')
# (228, 1798, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (229, 1737, 'Monday', 'AIR CANADA', 'TORONTO')
# (230, 3264, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (231, 2663, 'Saturday', 'JETBLUE', 'BOSTON')
# (232, 1321, 'Thursday', 'JETBLUE', 'NEW YORK-JFK')
# (233, 2377, 'Wednesday', 'UNITED', 'AUSTIN')
# (234, 3024, 'Thursday', 'ALASKA', 'SEATTLE')
# (235, 713, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (236, 2385, 'Wednesday', 'UNITED INTL', 'SYDNEY')
# (237, 1732, 'Monday', 'AIR CANADA', 'TORONTO')
# (238, 2878, 'Friday', 'EVA AIR', 'TAIPEI')
# (239, 1607, 'Thursday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (240, 2562, 'Saturday', 'JETBLUE', 'BOSTON')
# (241, 2682, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (242, 1771, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (243, 3265, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (244, 2937, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (245, 2550, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (246, 810, 'Sunday', 'ALASKA', 'BALTIMORE')
# (248, 664, 'Thursday', 'UNITED', 'NEWARK')
# (249, 2894, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (250, 2703, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (251, 2364, 'Wednesday', 'UNITED', 'AUSTIN')
# (252, 1038, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (253, 3030, 'Tuesday', 'UNITED', 'PORTLAND')
# (254, 1438, 'Saturday', 'UNITED', 'PORTLAND')
# (255, 1634, 'Thursday', 'KOREAN AIR', 'SEOUL')
# (256, 2142, 'Wednesday', 'AIR CANADA', 'VANCOUVER')
# (257, 3198, 'Tuesday', 'UNITED', 'ONTARIO (CALIF)')
# (259, 2658, 'Saturday', 'AEROMEXICO', 'MEXICO CITY')
# (260, 282, 'Thursday', 'UNITED', 'BALTIMORE')
# (261, 100, 'Tuesday', 'UNITED', 'WASHINGTON DC-DULLES')
# (263, 3243, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (265, 1646, 'Saturday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (267, 662, 'Thursday', 'UNITED', 'NEWARK')
# (269, 622, 'Thursday', 'ALASKA', 'NEWARK')
# (270, 2132, 'Wednesday', 'FRONTIER', 'DENVER')
# (271, 2395, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (272, 2126, 'Monday', 'UNITED INTL', 'MEXICO CITY')
# (273, 325, 'Thursday', 'UNITED', 'BURBANK')
# (274, 2531, 'Saturday', 'UNITED', 'NEWARK')
# (275, 3210, 'Thursday', 'AMERICAN', 'LOS ANGELES')
# (276, 1816, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (278, 2852, 'Tuesday', 'UNITED', 'SEATTLE')
# (279, 3063, 'Sunday', 'PHILIPPINE AIRLINES', 'MANILA')
# (280, 1923, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (281, 2785, 'Sunday', 'WOW', 'REYKJAVIK')
# (282, 415, 'Saturday', 'UNITED', 'PHOENIX')
# (283, 419, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (284, 1669, 'Saturday', 'EMIRATES', 'DUBAI')
# (285, 420, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (289, 2473, 'Friday', 'UNITED', 'DENVER')
# (290, 1769, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (291, 2122, 'Thursday', 'CATHAY PACIFIC', 'HONG KONG')
# (292, 2921, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (293, 1180, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (294, 836, 'Sunday', 'ALASKA', 'SEATTLE')
# (295, 2899, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (296, 659, 'Thursday', 'UNITED', 'NEWARK')
# (297, 2240, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (298, 323, 'Thursday', 'UNITED', 'BURBANK')
# (299, 506, 'Sunday', 'ALASKA', 'PORTLAND')
# (300, 2864, 'Tuesday', 'UNITED', 'SEATTLE')
# (302, 2654, 'Saturday', 'AEROMEXICO', 'MEXICO CITY')
# (303, 2662, 'Friday', 'UNITED', 'RALEIGH-DURHAM')
# (304, 430, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (305, 1281, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (306, 2966, 'Wednesday', 'AMERICAN', 'CHARLOTTE')
# (307, 1968, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (309, 3249, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (310, 2941, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (311, 2810, 'Thursday', 'DELTA', 'LOS ANGELES')
# (313, 2613, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (314, 1914, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (315, 194, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (316, 2316, 'Tuesday', 'UNITED', 'SAN ANTONIO')
# (317, 1430, 'Wednesday', 'UNITED', 'LAS VEGAS')
# (318, 2881, 'Friday', 'EVA AIR', 'TAIPEI')
# (319, 1864, 'Tuesday', 'UNITED', 'LOS ANGELES')
# (321, 1702, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (322, 653, 'Friday', 'UNITED INTL', 'MUNICH')
# (323, 1500, 'Wednesday', 'DELTA', 'LOS ANGELES')
# (324, 2660, 'Saturday', 'JETBLUE', 'BOSTON')
# (325, 656, 'Thursday', 'UNITED', 'NEWARK')
# (326, 1908, 'Tuesday', 'UNITED', 'BOSTON')
# (327, 427, 'Sunday', 'UNITED', 'HONOLULU')
# (328, 630, 'Thursday', 'ALASKA', 'NEWARK')
# (329, 1928, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (331, 1587, 'Wednesday', 'DELTA', 'SALT LAKE CITY')
# (332, 1830, 'Monday', 'TURKISH AIRLINES', 'ISTANBUL')
# (333, 2516, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (334, 1076, 'Friday', 'AIR CANADA', 'CALGARY')
# (335, 2943, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (336, 2939, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (337, 605, 'Thursday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (338, 288, 'Thursday', 'UNITED', 'BALTIMORE')
# (339, 2622, 'Tuesday', 'JETBLUE', 'BOSTON')
# (340, 3124, 'Sunday', 'COPA', 'PANAMA CITY')
# (341, 2431, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (342, 1657, 'Saturday', 'EMIRATES', 'DUBAI')
# (343, 879, 'Tuesday', 'ALASKA', 'RALEIGH-DURHAM')
# (344, 886, 'Tuesday', 'ALASKA', 'RALEIGH-DURHAM')
# (345, 1557, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (346, 806, 'Sunday', 'ALASKA', 'BALTIMORE')
# (347, 692, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (348, 196, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (349, 855, 'Tuesday', 'ALASKA', 'PORTLAND')
# (350, 3010, 'Wednesday', 'AMERICAN', 'MIAMI')
# (351, 2338, 'Wednesday', 'UNITED', 'AUSTIN')
# (353, 1891, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (354, 2403, 'Wednesday', 'UNITED INTL', 'SYDNEY')
# (355, 448, 'Sunday', 'UNITED', 'HONOLULU')
# (356, 1182, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (357, 1609, 'Thursday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (360, 3260, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (361, 308, 'Thursday', 'UNITED', 'SAN DIEGO')
# (362, 972, 'Friday', 'LUFTHANSA', 'MUNICH')
# (363, 1553, 'Wednesday', 'AIR CHINA', 'BEIJING')
# (364, 1812, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (365, 1061, 'Friday', 'AIR CANADA', 'CALGARY')
# (366, 1811, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (367, 2714, 'Friday', 'UNITED', 'KAHULUI')
# (368, 2724, 'Friday', 'UNITED', 'KAHULUI')
# (369, 229, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (370, 1949, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (371, 1897, 'Monday', 'LUFTHANSA', 'MUNICH')
# (372, 2239, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (373, 479, 'Sunday', 'ALASKA', 'PORTLAND')
# (375, 2170, 'Wednesday', 'FRONTIER', 'DENVER')
# (377, 2971, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (378, 2442, 'Tuesday', 'JETBLUE', 'BOSTON')
# (379, 3207, 'Thursday', 'AMERICAN', 'LOS ANGELES')
# (380, 2926, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (381, 859, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (383, 2918, 'Thursday', 'DELTA', 'SEATTLE')
# (384, 944, 'Thursday', 'AIR CANADA', 'VANCOUVER')
# (385, 418, 'Sunday', 'UNITED', 'HONOLULU')
# (386, 1323, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (387, 2480, 'Friday', 'UNITED', 'DENVER')
# (388, 1750, 'Monday', 'LUFTHANSA', 'MUNICH')
# (389, 1131, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (390, 3193, 'Sunday', 'CATHAY PACIFIC', 'HONG KONG')
# (391, 1322, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (392, 2166, 'Wednesday', 'FRONTIER', 'DENVER')
# (393, 555, 'Thursday', 'EMIRATES', 'DUBAI')
# (394, 1757, 'Monday', 'LUFTHANSA', 'MUNICH')
# (395, 1065, 'Friday', 'AIR CANADA', 'CALGARY')
# (396, 1298, 'Thursday', 'JETBLUE', 'NEW YORK-JFK')
# (397, 396, 'Friday', 'ALASKA', 'INDIANAPOLIS')
# (398, 1383, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (399, 1028, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (400, 1813, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (401, 331, 'Friday', 'ALASKA', 'SAN DIEGO')
# (403, 3091, 'Sunday', 'ALASKA', 'NEWARK')
# (404, 1315, 'Thursday', 'JETBLUE', 'NEW YORK-JFK')
# (406, 352, 'Friday', 'LUFTHANSA', 'FRANKFURT')
# (407, 1659, 'Saturday', 'EMIRATES', 'DUBAI')
# (408, 1964, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (409, 790, 'Thursday', 'UNITED INTL', 'SAN JOSE DEL CABO')
# (410, 1445, 'Saturday', 'UNITED', 'PORTLAND')
# (411, 293, 'Thursday', 'UNITED', 'SAN DIEGO')
# (414, 294, 'Thursday', 'UNITED', 'SAN DIEGO')
# (415, 763, 'Thursday', 'AIR CANADA', 'TORONTO')
# (416, 1701, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (417, 2472, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (418, 2892, 'Sunday', 'WOW', 'REYKJAVIK')
# (419, 2612, 'Tuesday', 'JETBLUE', 'BOSTON')
# (421, 263, 'Friday', 'AIR CANADA', 'TORONTO')
# (422, 3103, 'Sunday', 'ALASKA', 'NEWARK')
# (423, 2275, 'Wednesday', 'WOW', 'REYKJAVIK')
# (424, 2688, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (426, 2678, 'Friday', 'UNITED', 'ORLANDO')
# (427, 539, 'Thursday', 'EMIRATES', 'DUBAI')
# (428, 2496, 'Friday', 'UNITED', 'DENVER')
# (430, 2916, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (431, 2299, 'Tuesday', 'UNITED', 'SAN ANTONIO')
# (432, 1853, 'Sunday', 'ALASKA', 'KAHULUI')
# (433, 3014, 'Tuesday', 'UNITED', 'PORTLAND')
# (434, 1133, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (435, 2874, 'Friday', 'EVA AIR', 'TAIPEI')
# (436, 816, 'Sunday', 'ALASKA', 'BALTIMORE')
# (437, 249, 'Thursday', 'UNITED', 'NASHVILLE')
# (438, 2204, 'Wednesday', 'AER LINGUS', 'DUBLIN')
# (439, 2748, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (440, 335, 'Wednesday', 'SOUTHWEST', 'PHOENIX')
# (442, 1922, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (443, 1540, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (444, 715, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (447, 557, 'Thursday', 'EMIRATES', 'DUBAI')
# (448, 1279, 'Thursday', 'CHINA SOUTHERN', 'WUHAN')
# (449, 3253, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (450, 858, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (451, 1529, 'Wednesday', 'ALASKA', 'LOS ANGELES')
# (452, 2788, 'Sunday', 'WOW', 'REYKJAVIK')
# (453, 2517, 'Saturday', 'UNITED', 'NEWARK')
# (454, 792, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (455, 2056, 'Friday', 'UNITED', 'NEWARK')
# (456, 3184, 'Thursday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (457, 1767, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (458, 1192, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (459, 1211, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (461, 864, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (462, 817, 'Sunday', 'ALASKA', 'PORTLAND')
# (463, 832, 'Sunday', 'ALASKA', 'SEATTLE')
# (464, 272, 'Thursday', 'UNITED', 'LOS ANGELES')
# (465, 1196, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (466, 2205, 'Thursday', 'CATHAY PACIFIC', 'HONG KONG')
# (467, 2264, 'Wednesday', 'UNITED', 'LOS ANGELES')
# (468, 1504, 'Wednesday', 'DELTA', 'LOS ANGELES')
# (469, 1489, 'Wednesday', 'HAWAIIAN AIR', 'HONOLULU')
# (470, 497, 'Sunday', 'UNITED', 'DENVER')
# (471, 1115, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (472, 1532, 'Wednesday', 'JETBLUE', 'NEW YORK-JFK')
# (473, 3093, 'Tuesday', 'UNITED', 'SPOKANE')
# (474, 1762, 'Monday', 'LUFTHANSA', 'MUNICH')
# (475, 2023, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (476, 2495, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (477, 658, 'Friday', 'UNITED INTL', 'MUNICH')
# (478, 781, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (479, 2330, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (480, 3220, 'Thursday', 'AMERICAN', 'LOS ANGELES')
# (481, 1474, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (482, 250, 'Thursday', 'UNITED', 'NASHVILLE')
# (483, 1120, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (484, 2422, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (485, 414, 'Sunday', 'UNITED', 'HOUSTON-BUSH')
# (486, 2289, 'Wednesday', 'QANTAS', 'SYDNEY')
# (487, 254, 'Friday', 'AIR CANADA', 'TORONTO')
# (488, 3022, 'Tuesday', 'UNITED', 'PORTLAND')
# (490, 513, 'Sunday', 'ALASKA', 'PORTLAND')
# (491, 3181, 'Thursday', 'DELTA', 'LOS ANGELES')
# (492, 2459, 'Friday', 'UNITED', 'DENVER')
# (493, 2123, 'Friday', 'JETBLUE', 'LONG BEACH')
# (494, 1343, 'Tuesday', 'UNITED INTL', 'KANSAI')
# (495, 2851, 'Tuesday', 'UNITED', 'SEATTLE')
# (496, 481, 'Sunday', 'ALASKA', 'PORTLAND')
# (497, 2870, 'Wednesday', 'UNITED', 'WASHINGTON DC-DULLES')
# (498, 1516, 'Wednesday', 'INTERJET', 'GUADALAJARA')
# (500, 2391, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (501, 2137, 'Wednesday', 'AIR CANADA', 'VANCOUVER')
# (502, 1815, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (503, 2479, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (504, 3082, 'Tuesday', 'UNITED', 'SPOKANE')
# (505, 749, 'Sunday', 'ALASKA', 'NEW YORK-JFK')
# (506, 1990, 'Friday', 'AIR FRANCE/KLM', 'AMSTERDAM')
# (507, 1381, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (508, 1174, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (509, 2007, 'Friday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (510, 1685, 'Saturday', 'CATHAY PACIFIC', 'HONG KONG')
# (511, 445, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (513, 1967, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (514, 2371, 'Tuesday', 'JETBLUE', 'FT. LAUDERDALE')
# (515, 671, 'Thursday', 'UNITED', 'NEWARK')
# (517, 1169, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (519, 745, 'Thursday', 'AIR CANADA', 'TORONTO')
# (520, 2812, 'Thursday', 'DELTA', 'LOS ANGELES')
# (521, 2760, 'Thursday', 'DELTA', 'ATLANTA')
# (523, 1679, 'Saturday', 'CATHAY PACIFIC', 'HONG KONG')
# (524, 2609, 'Tuesday', 'JETBLUE', 'BOSTON')
# (525, 2327, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (526, 1313, 'Thursday', 'JETBLUE', 'NEW YORK-JFK')
# (527, 1019, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (528, 846, 'Tuesday', 'ALASKA', 'PORTLAND')
# (529, 1460, 'Saturday', 'UNITED', 'PORTLAND')
# (530, 309, 'Thursday', 'UNITED', 'SAN DIEGO')
# (531, 2761, 'Wednesday', 'UNITED', 'AUSTIN')
# (533, 2066, 'Thursday', 'AMERICAN', 'PHILADELPHIA')
# (535, 2005, 'Friday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (536, 102, 'Tuesday', 'UNITED', 'WASHINGTON DC-DULLES')
# (537, 2491, 'Friday', 'ALASKA', 'SALT LAKE CITY')
# (538, 1167, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (539, 1660, 'Saturday', 'EMIRATES', 'DUBAI')
# (540, 3125, 'Sunday', 'ALASKA', 'NEWARK')
# (541, 2906, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (542, 1227, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (543, 641, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (544, 1478, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (546, 1797, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (547, 381, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (549, 2180, 'Wednesday', 'QANTAS', 'SYDNEY')
# (550, 2901, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (552, 2965, 'Wednesday', 'AMERICAN', 'CHARLOTTE')
# (553, 1654, 'Saturday', 'EMIRATES', 'DUBAI')
# (555, 1513, 'Wednesday', 'DELTA', 'LOS ANGELES')
# (556, 1628, 'Thursday', 'KOREAN AIR', 'SEOUL')
# (557, 274, 'Thursday', 'UNITED', 'LOS ANGELES')
# (558, 1745, 'Monday', 'AIR CANADA', 'TORONTO')
# (559, 1469, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (561, 406, 'Sunday', 'UNITED', 'HOUSTON-BUSH')
# (562, 2219, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (564, 2477, 'Tuesday', 'UNITED', 'HONOLULU')
# (565, 2374, 'Wednesday', 'UNITED', 'AUSTIN')
# (566, 447, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (567, 1353, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (568, 2382, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (569, 1142, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (570, 2317, 'Wednesday', 'QANTAS', 'SYDNEY')
# (571, 1249, 'Thursday', 'UNITED INTL', 'TOKYO-NARITA')
# (572, 2655, 'Saturday', 'JETBLUE', 'BOSTON')
# (573, 2604, 'Saturday', 'INTERJET', 'GUADALAJARA')
# (574, 1510, 'Wednesday', 'HAWAIIAN AIR', 'HONOLULU')
# (575, 1232, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (576, 2322, 'Wednesday', 'QANTAS', 'SYDNEY')
# (578, 2487, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (579, 2243, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (581, 1449, 'Wednesday', 'UNITED', 'LAS VEGAS')
# (582, 2032, 'Wednesday', 'UNITED', 'NEWARK')
# (583, 1588, 'Wednesday', 'UNITED INTL', 'HONG KONG')
# (584, 3194, 'Thursday', 'DELTA', 'LOS ANGELES')
# (585, 3116, 'Sunday', 'ALASKA', 'NEWARK')
# (586, 2920, 'Thursday', 'DELTA', 'SEATTLE')
# (587, 1440, 'Saturday', 'UNITED', 'PORTLAND')
# (588, 1596, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (589, 2207, 'Wednesday', 'AER LINGUS', 'DUBLIN')
# (590, 2651, 'Saturday', 'JETBLUE', 'BOSTON')
# (592, 2133, 'Wednesday', 'AIR CANADA', 'VANCOUVER')
# (594, 343, 'Friday', 'ALASKA', 'SAN DIEGO')
# (595, 1455, 'Saturday', 'UNITED', 'PORTLAND')
# (596, 901, 'Friday', 'AIR CANADA', 'TORONTO')
# (597, 1186, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (598, 554, 'Thursday', 'EMIRATES', 'DUBAI')
# (599, 333, 'Friday', 'ALASKA', 'SAN DIEGO')
# (601, 2437, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (602, 3012, 'Tuesday', 'UNITED', 'PORTLAND')
# (603, 1666, 'Saturday', 'EMIRATES', 'DUBAI')
# (604, 2008, 'Wednesday', 'UNITED', 'NEWARK')
# (606, 2998, 'Tuesday', 'UNITED', 'BURBANK')
# (607, 3111, 'Sunday', 'COPA', 'PANAMA CITY')
# (608, 577, 'Thursday', 'ALASKA', 'SEATTLE')
# (610, 3163, 'Thursday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (611, 2956, 'Tuesday', 'AMERICAN', 'NEW YORK-JFK')
# (612, 874, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (613, 3177, 'Thursday', 'DELTA', 'LOS ANGELES')
# (614, 831, 'Sunday', 'ALASKA', 'NASHVILLE')
# (615, 2379, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (616, 2006, 'Friday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (617, 3239, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (618, 2825, 'Tuesday', 'UNITED', 'BURBANK')
# (620, 2201, 'Thursday', 'SOUTHWEST', 'LAS VEGAS')
# (621, 644, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (622, 1286, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (623, 3042, 'Tuesday', 'UNITED', 'PORTLAND')
# (625, 336, 'Friday', 'ALASKA', 'SAN DIEGO')
# (627, 2426, 'Tuesday', 'UNITED', 'HONOLULU')
# (629, 3225, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (630, 1598, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (631, 2552, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (632, 2802, 'Tuesday', 'SOUTHWEST', 'PHOENIX')
# (633, 3128, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (634, 945, 'Friday', 'AIR CANADA', 'TORONTO')
# (635, 2564, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (636, 1707, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (637, 2873, 'Friday', 'EVA AIR', 'TAIPEI')
# (638, 2540, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (639, 462, 'Sunday', 'ALASKA', 'LAS VEGAS')
# (640, 1873, 'Tuesday', 'UNITED', 'BOSTON')
# (641, 1016, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (642, 370, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (643, 2151, 'Thursday', 'CATHAY PACIFIC', 'HONG KONG')
# (644, 1872, 'Sunday', 'ALASKA', 'KAHULUI')
# (645, 1576, 'Wednesday', 'DELTA', 'DETROIT')
# (646, 2541, 'Tuesday', 'JETBLUE', 'LONG BEACH')
# (647, 1301, 'Thursday', 'JETBLUE', 'NEW YORK-JFK')
# (648, 3040, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (649, 1360, 'Tuesday', 'UNITED INTL', 'PARIS-DE GAULLE')
# (650, 2469, 'Friday', 'UNITED', 'DENVER')
# (651, 543, 'Thursday', 'EMIRATES', 'DUBAI')
# (652, 2925, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (653, 2685, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (654, 2268, 'Wednesday', 'UNITED', 'LOS ANGELES')
# (656, 2041, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (657, 2167, 'Wednesday', 'FRONTIER', 'DENVER')
# (658, 3088, 'Tuesday', 'UNITED', 'SPOKANE')
# (659, 2948, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (660, 443, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (661, 278, 'Thursday', 'UNITED', 'BALTIMORE')
# (662, 2457, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (663, 1526, 'Wednesday', 'JETBLUE', 'NEW YORK-JFK')
# (664, 2689, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (665, 3055, 'Sunday', 'PHILIPPINE AIRLINES', 'MANILA')
# (666, 2136, 'Thursday', 'CATHAY PACIFIC', 'HONG KONG')
# (667, 1450, 'Wednesday', 'UNITED', 'LAS VEGAS')
# (668, 2415, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (669, 729, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (670, 2232, 'Thursday', 'SOUTHWEST', 'SANTA ANA')
# (671, 1452, 'Wednesday', 'UNITED', 'LAS VEGAS')
# (672, 1705, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (673, 1543, 'Wednesday', 'AIR CHINA', 'BEIJING')
# (674, 618, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (675, 1726, 'Monday', 'AIR CANADA', 'TORONTO')
# (676, 2209, 'Thursday', 'SOUTHWEST', 'LAS VEGAS')
# (677, 1786, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (678, 2625, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (679, 1760, 'Monday', 'LUFTHANSA', 'MUNICH')
# (680, 2732, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (681, 711, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (682, 943, 'Thursday', 'AIR CANADA', 'VANCOUVER')
# (684, 1910, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (685, 2027, 'Wednesday', 'UNITED', 'NEWARK')
# (688, 365, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (689, 3005, 'Thursday', 'UNITED', 'NASHVILLE')
# (690, 1502, 'Wednesday', 'HAWAIIAN AIR', 'HONOLULU')
# (691, 2621, 'Saturday', 'AEROMEXICO', 'MEXICO CITY')
# (692, 1639, 'Saturday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (693, 2733, 'Thursday', 'DELTA', 'LOS ANGELES')
# (694, 2021, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (695, 629, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (696, 3026, 'Tuesday', 'UNITED', 'PORTLAND')
# (697, 1671, 'Saturday', 'EMIRATES', 'DUBAI')
# (698, 3248, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (699, 684, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (701, 1905, 'Monday', 'LUFTHANSA', 'MUNICH')
# (703, 774, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (704, 2917, 'Thursday', 'DELTA', 'SEATTLE')
# (705, 1459, 'Saturday', 'UNITED', 'PORTLAND')
# (706, 1178, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (707, 2691, 'Friday', 'UNITED', 'ORLANDO')
# (708, 857, 'Tuesday', 'ALASKA', 'PORTLAND')
# (709, 3148, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (710, 1519, 'Wednesday', 'DELTA', 'LOS ANGELES')
# (711, 1126, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (712, 3269, 'Tuesday', 'UNITED', 'LAS VEGAS')
# (714, 1960, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (715, 2545, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (718, 2582, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (719, 358, 'Friday', 'ALASKA', 'NEWARK')
# (720, 2912, 'Thursday', 'DELTA', 'SEATTLE')
# (721, 2030, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (722, 2242, 'Wednesday', 'WOW', 'REYKJAVIK')
# (723, 2556, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (724, 853, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (725, 3168, 'Thursday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (726, 2234, 'Thursday', 'SOUTHWEST', 'SANTA ANA')
# (727, 2765, 'Sunday', 'WOW', 'REYKJAVIK')
# (728, 3092, 'Sunday', 'COPA', 'PANAMA CITY')
# (729, 285, 'Thursday', 'UNITED', 'BALTIMORE')
# (730, 1480, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (731, 3175, 'Thursday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (732, 2770, 'Wednesday', 'UNITED', 'AUSTIN')
# (733, 3033, 'Tuesday', 'UNITED', 'PORTLAND')
# (734, 1661, 'Saturday', 'EMIRATES', 'DUBAI')
# (735, 2634, 'Tuesday', 'JETBLUE', 'NEW YORK-JFK')
# (736, 1987, 'Friday', 'AIR FRANCE/KLM', 'AMSTERDAM')
# (737, 1861, 'Sunday', 'ALASKA', 'KAHULUI')
# (738, 1278, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (858, 818, 'Sunday', 'ALASKA', 'BALTIMORE')
# (739, 1841, 'Monday', 'TURKISH AIRLINES', 'ISTANBUL')
# (740, 341, 'Friday', 'ALASKA', 'SAN DIEGO')
# (741, 1978, 'Tuesday', 'UNITED', 'BALTIMORE')
# (743, 319, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (744, 1636, 'Thursday', 'KOREAN AIR', 'SEOUL')
# (745, 3292, 'Wednesday', 'SOUTHWEST', 'DENVER')
# (746, 3203, 'Tuesday', 'UNITED', 'ONTARIO (CALIF)')
# (747, 1898, 'Monday', 'LUFTHANSA', 'MUNICH')
# (748, 633, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (749, 1385, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (751, 2069, 'Thursday', 'AMERICAN', 'PHILADELPHIA')
# (752, 299, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (753, 2730, 'Friday', 'UNITED', 'KAHULUI')
# (754, 1676, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (755, 3282, 'Wednesday', 'SOUTHWEST', 'DENVER')
# (756, 2112, 'Tuesday', 'AMERICAN', 'PHOENIX')
# (757, 1986, 'Friday', 'AIR FRANCE/KLM', 'AMSTERDAM')
# (758, 2595, 'Tuesday', 'JETBLUE', 'BOSTON')
# (759, 814, 'Sunday', 'ALASKA', 'BALTIMORE')
# (760, 2551, 'Saturday', 'JETBLUE', 'BOSTON')
# (761, 1965, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (762, 2640, 'Tuesday', 'JETBLUE', 'NEW YORK-JFK')
# (763, 395, 'Friday', 'ALASKA', 'LOS ANGELES')
# (764, 728, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (765, 1215, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (766, 2314, 'Tuesday', 'UNITED', 'SAN ANTONIO')
# (767, 1718, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (768, 2383, 'Wednesday', 'UNITED INTL', 'SYDNEY')
# (769, 584, 'Thursday', 'JETBLUE', 'BOSTON')
# (770, 1770, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (771, 642, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (772, 1865, 'Sunday', 'ALASKA', 'KAHULUI')
# (773, 2100, 'Friday', 'JETBLUE', 'LONG BEACH')
# (774, 2647, 'Saturday', 'JETBLUE', 'BOSTON')
# (775, 1982, 'Friday', 'AIR FRANCE/KLM', 'AMSTERDAM')
# (776, 1973, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (777, 310, 'Tuesday', 'UNITED', 'WASHINGTON DC-DULLES')
# (778, 2386, 'Wednesday', 'UNITED INTL', 'SYDNEY')
# (779, 295, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (780, 2301, 'Wednesday', 'QANTAS', 'SYDNEY')
# (781, 1253, 'Thursday', 'CHINA EASTERN', 'SHANGHAI')
# (782, 1649, 'Saturday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (783, 3279, 'Wednesday', 'SOUTHWEST', 'DENVER')
# (784, 863, 'Tuesday', 'ALASKA', 'SEATTLE')
# (785, 2771, 'Thursday', 'DELTA', 'ATLANTA')
# (786, 1547, 'Wednesday', 'AIR CHINA', 'BEIJING')
# (787, 750, 'Thursday', 'AIR CANADA', 'TORONTO')
# (788, 2285, 'Wednesday', 'QANTAS', 'SYDNEY')
# (789, 3214, 'Tuesday', 'UNITED', 'SANTA BARBARA')
# (790, 2172, 'Wednesday', 'FRONTIER', 'DENVER')
# (791, 576, 'Thursday', 'JETBLUE', 'BOSTON')
# (792, 404, 'Saturday', 'UNITED', 'PHOENIX')
# (794, 2254, 'Wednesday', 'UNITED', 'LOS ANGELES')
# (795, 682, 'Thursday', 'UNITED', 'NEWARK')
# (796, 2028, 'Wednesday', 'UNITED', 'NEWARK')
# (798, 854, 'Tuesday', 'ALASKA', 'PORTLAND')
# (799, 1675, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (800, 1604, 'Thursday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (801, 534, 'Thursday', 'EMIRATES', 'DUBAI')
# (802, 2829, 'Tuesday', 'UNITED', 'BURBANK')
# (803, 1822, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (805, 1948, 'Tuesday', 'UNITED', 'BOSTON')
# (806, 2950, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (807, 2508, 'Saturday', 'UNITED', 'NEWARK')
# (808, 292, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (809, 876, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (810, 2120, 'Friday', 'JETBLUE', 'LONG BEACH')
# (811, 2764, 'Thursday', 'DELTA', 'ATLANTA')
# (812, 787, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (813, 2883, 'Friday', 'EVA AIR', 'TAIPEI')
# (814, 421, 'Sunday', 'UNITED', 'HONOLULU')
# (815, 2683, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (816, 2805, 'Tuesday', 'SOUTHWEST', 'PHOENIX')
# (817, 2554, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (818, 472, 'Sunday', 'UNITED', 'DENVER')
# (819, 2535, 'Tuesday', 'JETBLUE', 'LONG BEACH')
# (821, 613, 'Thursday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (822, 2694, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (823, 808, 'Sunday', 'ALASKA', 'BALTIMORE')
# (825, 574, 'Thursday', 'ALASKA', 'SEATTLE')
# (827, 2984, 'Wednesday', 'AMERICAN', 'CHARLOTTE')
# (828, 425, 'Sunday', 'UNITED', 'HONOLULU')
# (829, 3160, 'Thursday', 'DELTA', 'LOS ANGELES')
# (830, 2514, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (831, 802, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (832, 695, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (834, 841, 'Sunday', 'ALASKA', 'SEATTLE')
# (835, 2346, 'Wednesday', 'UNITED', 'AUSTIN')
# (836, 1667, 'Saturday', 'EMIRATES', 'DUBAI')
# (837, 552, 'Thursday', 'ALASKA', 'SEATTLE')
# (838, 2877, 'Friday', 'EVA AIR', 'TAIPEI')
# (839, 1276, 'Thursday', 'CHINA SOUTHERN', 'WUHAN')
# (840, 556, 'Thursday', 'ALASKA', 'SEATTLE')
# (841, 2184, 'Wednesday', 'QANTAS', 'SYDNEY')
# (842, 2991, 'Friday', 'UNITED', 'KAHULUI')
# (843, 501, 'Sunday', 'UNITED', 'KAHULUI')
# (844, 3206, 'Tuesday', 'UNITED', 'EUGENE')
# (846, 2586, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (847, 1988, 'Friday', 'AIR FRANCE/KLM', 'AMSTERDAM')
# (848, 834, 'Sunday', 'ALASKA', 'SEATTLE')
# (849, 1921, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (850, 870, 'Tuesday', 'ALASKA', 'SEATTLE')
# (851, 1931, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (852, 3238, 'Thursday', 'ALASKA', 'PORTLAND')
# (853, 1862, 'Sunday', 'ALASKA', 'KAHULUI')
# (854, 1601, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (855, 521, 'Thursday', 'EMIRATES', 'DUBAI')
# (856, 2542, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (857, 2294, 'Tuesday', 'UNITED', 'SAN ANTONIO')
# (860, 2393, 'Wednesday', 'UNITED INTL', 'SYDNEY')
# (862, 1573, 'Wednesday', 'DELTA', 'DETROIT')
# (863, 2633, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (864, 496, 'Sunday', 'ALASKA', 'PORTLAND')
# (865, 2043, 'Wednesday', 'UNITED', 'NEWARK')
# (867, 1687, 'Saturday', 'CATHAY PACIFIC', 'HONG KONG')
# (868, 2528, 'Tuesday', 'JETBLUE', 'LONG BEACH')
# (869, 1879, 'Tuesday', 'UNITED', 'BOSTON')
# (870, 2418, 'Tuesday', 'UNITED', 'HONOLULU')
# (871, 10, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (872, 371, 'Friday', 'LUFTHANSA', 'FRANKFURT')
# (873, 688, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (874, 1930, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (875, 1010, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (876, 3221, 'Thursday', 'AMERICAN', 'LOS ANGELES')
# (877, 2590, 'Saturday', 'INTERJET', 'GUADALAJARA')
# (878, 1690, 'Saturday', 'CATHAY PACIFIC', 'HONG KONG')
# (879, 519, 'Thursday', 'EMIRATES', 'DUBAI')
# (881, 3001, 'Wednesday', 'AMERICAN', 'MIAMI')
# (882, 1581, 'Wednesday', 'DELTA', 'DETROIT')
# (884, 1465, 'Wednesday', 'FRONTIER', 'DENVER')
# (885, 759, 'Thursday', 'AIR CANADA', 'TORONTO')
# (886, 1994, 'Tuesday', 'UNITED', 'BALTIMORE')
# (887, 3172, 'Thursday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (888, 2767, 'Wednesday', 'UNITED', 'AUSTIN')
# (890, 592, 'Thursday', 'JETBLUE', 'BOSTON')
# (891, 2298, 'Wednesday', 'QANTAS', 'SYDNEY')
# (892, 1933, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (893, 1929, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (894, 1794, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (895, 3256, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (897, 2611, 'Saturday', 'AEROMEXICO', 'MEXICO CITY')
# (898, 2416, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (899, 3122, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (900, 2693, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (901, 2121, 'Monday', 'UNITED INTL', 'MEXICO CITY')
# (902, 3086, 'Sunday', 'COPA', 'PANAMA CITY')
# (904, 1368, 'Tuesday', 'UNITED INTL', 'PARIS-DE GAULLE')
# (905, 1838, 'Monday', 'TURKISH AIRLINES', 'ISTANBUL')
# (906, 2329, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (907, 2605, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (908, 1829, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (910, 1138, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (911, 2987, 'Wednesday', 'AMERICAN', 'CHARLOTTE')
# (912, 2602, 'Saturday', 'INTERJET', 'GUADALAJARA')
# (913, 1784, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (914, 2103, 'Friday', 'JETBLUE', 'LONG BEACH')
# (915, 2872, 'Wednesday', 'UNITED', 'WASHINGTON DC-DULLES')
# (916, 2013, 'Wednesday', 'UNITED', 'NEWARK')
# (917, 2841, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (918, 1883, 'Tuesday', 'UNITED', 'BOSTON')
# (919, 1013, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (920, 500, 'Sunday', 'ALASKA', 'PORTLAND')
# (923, 2790, 'Sunday', 'WOW', 'REYKJAVIK')
# (924, 2106, 'Friday', 'JETBLUE', 'LONG BEACH')
# (926, 3275, 'Tuesday', 'UNITED', 'LAS VEGAS')
# (927, 727, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (928, 3237, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (929, 837, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (930, 2756, 'Thursday', 'DELTA', 'ATLANTA')
# (931, 408, 'Saturday', 'UNITED', 'PHOENIX')
# (932, 2060, 'Thursday', 'AMERICAN', 'PHILADELPHIA')
# (933, 413, 'Saturday', 'UNITED', 'PHOENIX')
# (934, 1944, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (935, 2979, 'Wednesday', 'AMERICAN', 'CHARLOTTE')
# (936, 2539, 'Tuesday', 'JETBLUE', 'LONG BEACH')
# (937, 3011, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (939, 1738, 'Monday', 'AIR CANADA', 'TORONTO')
# (940, 2726, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (941, 1375, 'Tuesday', 'UNITED INTL', 'PARIS-DE GAULLE')
# (942, 1610, 'Thursday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (944, 2955, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (945, 1803, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (946, 1231, 'Thursday', 'ANA ALL NIPPON', 'TOKYO-NARITA')
# (947, 2256, 'Saturday', 'UNITED', 'BAKERSFIELD')
# (948, 2310, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (949, 2701, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (950, 429, 'Sunday', 'UNITED', 'HONOLULU')
# (951, 734, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (952, 1173, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (953, 324, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (954, 2381, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (955, 1527, 'Wednesday', 'ALASKA', 'LOS ANGELES')
# (956, 273, 'Thursday', 'UNITED', 'LOS ANGELES')
# (957, 1239, 'Thursday', 'UNITED INTL', 'TOKYO-NARITA')
# (958, 825, 'Sunday', 'ALASKA', 'SEATTLE')
# (959, 807, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (960, 1361, 'Tuesday', 'UNITED INTL', 'KANSAI')
# (961, 2681, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (962, 1584, 'Wednesday', 'DELTA', 'SALT LAKE CITY')
# (963, 712, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (964, 234, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (965, 3150, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (966, 2777, 'Thursday', 'DELTA', 'ATLANTA')
# (967, 2451, 'Friday', 'ALASKA', 'SALT LAKE CITY')
# (968, 1756, 'Monday', 'LUFTHANSA', 'MUNICH')
# (970, 2150, 'Wednesday', 'FRONTIER', 'DENVER')
# (971, 1197, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (972, 2347, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (973, 440, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (974, 1439, 'Wednesday', 'FRONTIER', 'DENVER')
# (975, 730, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (976, 2747, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (977, 1304, 'Thursday', 'JETBLUE', 'NEW YORK-JFK')
# (978, 2249, 'Saturday', 'UNITED', 'BAKERSFIELD')
# (979, 700, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (980, 2161, 'Wednesday', 'FRONTIER', 'DENVER')
# (981, 3073, 'Sunday', 'PHILIPPINE AIRLINES', 'MANILA')
# (982, 3224, 'Thursday', 'ALASKA', 'PORTLAND')
# (984, 2749, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (985, 2063, 'Thursday', 'AMERICAN', 'PHILADELPHIA')
# (986, 2618, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (987, 1859, 'Sunday', 'ALASKA', 'KAHULUI')
# (988, 2465, 'Friday', 'UNITED', 'DENVER')
# (989, 3267, 'Tuesday', 'UNITED', 'LAS VEGAS')
# (990, 2972, 'Wednesday', 'AMERICAN', 'CHARLOTTE')
# (991, 1899, 'Monday', 'LUFTHANSA', 'MUNICH')
# (992, 2039, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (993, 1153, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (994, 1134, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (995, 198, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (996, 1296, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (997, 2680, 'Friday', 'UNITED', 'ORLANDO')
# (998, 2650, 'Saturday', 'JETBLUE', 'BOSTON')
# (999, 1534, 'Wednesday', 'ALASKA', 'LOS ANGELES')
# (1000, 1575, 'Wednesday', 'UNITED INTL', 'HONG KONG')
# (1001, 2424, 'Tuesday', 'UNITED', 'HONOLULU')
# (1002, 1071, 'Friday', 'AIR CANADA', 'CALGARY')
# (1003, 2798, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (1004, 2193, 'Wednesday', 'AER LINGUS', 'DUBLIN')
# (1005, 328, 'Thursday', 'UNITED', 'BURBANK')
# (1006, 2967, 'Tuesday', 'UNITED', 'HONOLULU')
# (1007, 1521, 'Wednesday', 'DELTA', 'LOS ANGELES')
# (1009, 2813, 'Thursday', 'DELTA', 'LOS ANGELES')
# (1010, 3130, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (1011, 1764, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (1012, 227, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (1013, 1825, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (1014, 1483, 'Wednesday', 'AVIANCA', 'SAN SALVADOR')
# (1016, 2853, 'Tuesday', 'UNITED', 'SEATTLE')
# (1017, 1782, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (1018, 1951, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (1019, 329, 'Wednesday', 'SOUTHWEST', 'PHOENIX')
# (1020, 1633, 'Thursday', 'KOREAN AIR', 'SEOUL')
# (1021, 927, 'Friday', 'AIR CANADA', 'TORONTO')
# (1022, 258, 'Friday', 'AIR CANADA', 'TORONTO')
# (1023, 2022, 'Wednesday', 'UNITED', 'NEWARK')
# (1025, 3263, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (1026, 627, 'Thursday', 'ALASKA', 'NEWARK')
# (1027, 619, 'Thursday', 'ALASKA', 'NEWARK')
# (1028, 2961, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (1029, 2529, 'Tuesday', 'JETBLUE', 'LONG BEACH')
# (1030, 2202, 'Wednesday', 'AER LINGUS', 'DUBLIN')
# (1031, 2854, 'Tuesday', 'UNITED', 'SEATTLE')
# (1032, 2265, 'Wednesday', 'UNITED', 'LOS ANGELES')
# (1033, 2359, 'Wednesday', 'UNITED', 'AUSTIN')
# (1035, 1625, 'Thursday', 'KOREAN AIR', 'SEOUL')
# (1036, 1854, 'Wednesday', 'SOUTHWEST', 'SAN DIEGO')
# (1037, 982, 'Friday', 'LUFTHANSA', 'MUNICH')
# (1040, 1620, 'Thursday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (1041, 1419, 'Saturday', 'UNITED', 'KANSAS CITY')
# (1042, 900, 'Tuesday', 'ALASKA', 'RALEIGH-DURHAM')
# (1043, 2159, 'Saturday', 'CHINA EASTERN', 'QINGDAO')
# (1044, 2649, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (1045, 2784, 'Thursday', 'DELTA', 'ATLANTA')
# (1046, 693, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (1047, 782, 'Thursday', 'UNITED INTL', 'SAN JOSE DEL CABO')
# (1048, 677, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (1051, 771, 'Sunday', 'ALASKA', 'NEW YORK-JFK')
# (1052, 342, 'Friday', 'LUFTHANSA', 'FRANKFURT')
# (1053, 3180, 'Thursday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (1054, 2659, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (1055, 2698, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (1056, 454, 'Sunday', 'UNITED', 'DALLAS-FT. WORTH')
# (1057, 1530, 'Wednesday', 'JETBLUE', 'NEW YORK-JFK')
# (1058, 3071, 'Sunday', 'PHILIPPINE AIRLINES', 'MANILA')
# (1059, 2996, 'Wednesday', 'AMERICAN', 'MIAMI')
# (1060, 563, 'Thursday', 'ALASKA', 'SEATTLE')
# (1061, 2296, 'Wednesday', 'WOW', 'REYKJAVIK')
# (1062, 2467, 'Friday', 'UNITED', 'DENVER')
# (1063, 2789, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (1064, 2641, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (1065, 345, 'Friday', 'ALASKA', 'SAN DIEGO')
# (1066, 1246, 'Thursday', 'UNITED INTL', 'TOKYO-NARITA')
# (1067, 1416, 'Wednesday', 'UNITED', 'LAS VEGAS')
# (1068, 1100, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (1069, 1881, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (1070, 2458, 'Friday', 'ALASKA', 'SALT LAKE CITY')
# (1071, 3131, 'Sunday', 'ALASKA', 'NEWARK')
# (1072, 2713, 'Thursday', 'DELTA', 'LOS ANGELES')
# (1073, 2844, 'Tuesday', 'UNITED', 'SEATTLE')
# (1074, 1299, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (1075, 2000, 'Wednesday', 'UNITED', 'NEWARK')
# (1076, 245, 'Thursday', 'UNITED', 'NASHVILLE')
# (1078, 1920, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (1079, 1282, 'Thursday', 'CHINA SOUTHERN', 'WUHAN')
# (1080, 297, 'Thursday', 'UNITED', 'SAN DIEGO')
# (1081, 1486, 'Wednesday', 'FRONTIER', 'DENVER')
# (1082, 2454, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (1083, 2430, 'Tuesday', 'UNITED', 'HONOLULU')
# (1084, 2309, 'Tuesday', 'UNITED', 'SAN ANTONIO')
# (1085, 2849, 'Tuesday', 'UNITED', 'SEATTLE')
# (1086, 2875, 'Friday', 'EVA AIR', 'TAIPEI')
# (1087, 649, 'Friday', 'UNITED INTL', 'MUNICH')
# ...
# (2464, 3209, 'Tuesday', 'UNITED', 'SANTA BARBARA')
# (2466, 586, 'Thursday', 'JETBLUE', 'BOSTON')
# (2467, 1763, 'Monday', 'LUFTHANSA', 'MUNICH')
# (2468, 275, 'Thursday', 'UNITED', 'LOS ANGELES')
# (2469, 2587, 'Tuesday', 'JETBLUE', 'BOSTON')
# (2470, 326, 'Thursday', 'UNITED', 'BURBANK')
# (2471, 305, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (2472, 2373, 'Tuesday', 'JETBLUE', 'FT. LAUDERDALE')
# (2473, 1015, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (2474, 904, 'Friday', 'AIR CANADA', 'TORONTO')
# (2475, 2303, 'Tuesday', 'UNITED', 'SAN ANTONIO')
# (2476, 599, 'Thursday', 'JETBLUE', 'BOSTON')
# (2477, 1363, 'Tuesday', 'UNITED INTL', 'PARIS-DE GAULLE')
# (2478, 1715, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2479, 1565, 'Wednesday', 'UNITED INTL', 'HONG KONG')
# (2480, 2441, 'Tuesday', 'UNITED', 'HONOLULU')
# (2481, 428, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (2482, 1842, 'Monday', 'TURKISH AIRLINES', 'ISTANBUL')
# (2483, 877, 'Tuesday', 'ALASKA', 'SEATTLE')
# (2484, 1589, 'Thursday', 'SOUTHWEST', 'LOS ANGELES')
# (2485, 850, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (2486, 3241, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (2487, 1819, 'Sunday', 'ALASKA', 'RALEIGH-DURHAM')
# (2489, 2915, 'Thursday', 'DELTA', 'SEATTLE')
# (2490, 1095, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (2491, 1993, 'Tuesday', 'UNITED', 'BALTIMORE')
# (2492, 1267, 'Thursday', 'UNITED INTL', 'TOKYO-NARITA')
# (2493, 2233, 'Wednesday', 'AER LINGUS', 'DUBLIN')
# (2494, 1309, 'Thursday', 'JETBLUE', 'NEW YORK-JFK')
# (2495, 517, 'Sunday', 'UNITED', 'FT. LAUDERDALE')
# (2496, 615, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (2497, 2350, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (2498, 3027, 'Thursday', 'ALASKA', 'SEATTLE')
# (2501, 2174, 'Wednesday', 'FRONTIER', 'DENVER')
# (2502, 1089, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (2503, 1539, 'Wednesday', 'AIR CHINA', 'BEIJING')
# (2504, 528, 'Thursday', 'ALASKA', 'PUERTO VALLARTA')
# (2505, 474, 'Sunday', 'UNITED', 'DENVER')
# (2506, 1204, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (2507, 892, 'Tuesday', 'ALASKA', 'RALEIGH-DURHAM')
# (2508, 2601, 'Tuesday', 'JETBLUE', 'BOSTON')
# (2509, 1846, 'Monday', 'TURKISH AIRLINES', 'ISTANBUL')
# (2510, 628, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (2511, 2156, 'Wednesday', 'FRONTIER', 'DENVER')
# (2512, 2175, 'Wednesday', 'FRONTIER', 'DENVER')
# (2513, 1867, 'Tuesday', 'UNITED', 'LOS ANGELES')
# (2514, 457, 'Sunday', 'ALASKA', 'LAS VEGAS')
# (2517, 1063, 'Friday', 'AIR CANADA', 'CALGARY')
# (2518, 1183, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (2519, 1943, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2520, 1619, 'Thursday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (2521, 2923, 'Thursday', 'DELTA', 'SEATTLE')
# (2522, 1327, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (2523, 3031, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (2525, 796, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (2526, 255, 'Friday', 'AIR CANADA', 'TORONTO')
# (2527, 1871, 'Sunday', 'ALASKA', 'KAHULUI')
# (2528, 2591, 'Tuesday', 'JETBLUE', 'BOSTON')
# (2529, 3137, 'Sunday', 'ALASKA', 'NEWARK')
# (2530, 2076, 'Friday', 'JETBLUE', 'LONG BEACH')
# (2531, 489, 'Sunday', 'ALASKA', 'PORTLAND')
# (2532, 2419, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (2533, 2910, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (2535, 2513, 'Saturday', 'UNITED', 'NEWARK')
# (2536, 2002, 'Friday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2537, 3274, 'Tuesday', 'UNITED', 'LAS VEGAS')
# (2538, 1224, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (2539, 924, 'Friday', 'AIR CANADA', 'TORONTO')
# (2541, 3197, 'Sunday', 'CATHAY PACIFIC', 'HONG KONG')
# (2543, 1781, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (2544, 3077, 'Tuesday', 'UNITED', 'SPOKANE')
# (2545, 606, 'Thursday', 'JETBLUE', 'BOSTON')
# (2546, 1412, 'Saturday', 'UNITED', 'KANSAS CITY')
# (2547, 2699, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (2548, 2792, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (2549, 296, 'Thursday', 'UNITED', 'SAN DIEGO')
# (2550, 2819, 'Thursday', 'DELTA', 'LOS ANGELES')
# (2551, 1869, 'Sunday', 'ALASKA', 'KAHULUI')
# (2552, 1778, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (2553, 1545, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (2554, 2746, 'Thursday', 'DELTA', 'ATLANTA')
# (2555, 669, 'Thursday', 'UNITED', 'NEWARK')
# (2557, 984, 'Friday', 'LUFTHANSA', 'MUNICH')
# (2558, 1111, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (2559, 2253, 'Wednesday', 'WOW', 'REYKJAVIK')
# (2560, 3285, 'Wednesday', 'SOUTHWEST', 'DENVER')
# (2561, 2559, 'Saturday', 'JETBLUE', 'BOSTON')
# (2563, 1332, 'Tuesday', 'UNITED INTL', 'SHANGHAI')
# (2564, 525, 'Thursday', 'ALASKA', 'PUERTO VALLARTA')
# (2565, 2365, 'Tuesday', 'JETBLUE', 'FT. LAUDERDALE')
# (2566, 867, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (2567, 392, 'Friday', 'ALASKA', 'LOS ANGELES')
# (2568, 2401, 'Wednesday', 'UNITED INTL', 'SYDNEY')
# (2569, 1122, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (2571, 2176, 'Wednesday', 'FRONTIER', 'DENVER')
# (2572, 2522, 'Friday', 'ALASKA', 'SALT LAKE CITY')
# (2573, 2594, 'Saturday', 'INTERJET', 'GUADALAJARA')
# (2574, 2140, 'Wednesday', 'AIR CANADA', 'VANCOUVER')
# (2575, 2087, 'Friday', 'JETBLUE', 'LONG BEACH')
# (2576, 1207, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (2577, 581, 'Thursday', 'JETBLUE', 'BOSTON')
# (2578, 2855, 'Tuesday', 'UNITED', 'SEATTLE')
# (2579, 2450, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (2580, 2900, 'Sunday', 'WOW', 'REYKJAVIK')
# (2581, 2163, 'Wednesday', 'FRONTIER', 'DENVER')
# (2582, 2817, 'Thursday', 'DELTA', 'LOS ANGELES')
# (2583, 1655, 'Saturday', 'EMIRATES', 'DUBAI')
# (2584, 608, 'Thursday', 'JETBLUE', 'BOSTON')
# (2585, 2757, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2587, 1365, 'Tuesday', 'UNITED INTL', 'PARIS-DE GAULLE')
# (2588, 2141, 'Wednesday', 'FRONTIER', 'DENVER')
# (2589, 1800, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (2590, 3143, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (2591, 2378, 'Tuesday', 'JETBLUE', 'FT. LAUDERDALE')
# (2592, 197, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (2593, 1288, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (2594, 287, 'Thursday', 'UNITED', 'BALTIMORE')
# (2595, 409, 'Sunday', 'UNITED', 'HOUSTON-BUSH')
# (2596, 1680, 'Saturday', 'CATHAY PACIFIC', 'HONG KONG')
# (2597, 736, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (2598, 1040, 'Friday', 'AIR CANADA', 'CALGARY')
# (2599, 1995, 'Tuesday', 'UNITED', 'BALTIMORE')
# (2600, 889, 'Friday', 'AIR CANADA', 'TORONTO')
# (2601, 626, 'Tuesday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (2602, 1188, 'Tuesday', 'SOUTHWEST', 'LAS VEGAS')
# (2603, 2124, 'Friday', 'JETBLUE', 'LONG BEACH')
# (2604, 1788, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (2605, 1736, 'Monday', 'AIR CANADA', 'TORONTO')
# (2606, 509, 'Sunday', 'ALASKA', 'PORTLAND')
# (2607, 1106, 'Thursday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (2608, 1454, 'Wednesday', 'UNITED', 'LAS VEGAS')
# (2609, 391, 'Friday', 'ALASKA', 'INDIANAPOLIS')
# (2610, 1974, 'Tuesday', 'UNITED', 'BALTIMORE')
# (2611, 583, 'Thursday', 'ALASKA', 'SEATTLE')
# (2612, 2251, 'Wednesday', 'WOW', 'REYKJAVIK')
# (2613, 1888, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (2614, 1976, 'Tuesday', 'UNITED', 'BALTIMORE')
# (2615, 2290, 'Wednesday', 'WOW', 'REYKJAVIK')
# (2616, 1966, 'Tuesday', 'UNITED', 'BALTIMORE')
# (2617, 3284, 'Wednesday', 'SOUTHWEST', 'DENVER')
# (2618, 405, 'Sunday', 'UNITED', 'HOUSTON-BUSH')
# (2619, 1441, 'Wednesday', 'UNITED', 'LAS VEGAS')
# (2620, 2031, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (2621, 3287, 'Wednesday', 'SOUTHWEST', 'DENVER')
# (2622, 101, 'Tuesday', 'UNITED', 'WASHINGTON DC-DULLES')
# (2623, 985, 'Friday', 'LUFTHANSA', 'MUNICH')
# (2624, 1837, 'Monday', 'TURKISH AIRLINES', 'ISTANBUL')
# (2625, 1047, 'Friday', 'AIR CANADA', 'CALGARY')
# (2626, 779, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (2627, 2704, 'Tuesday', 'SOUTHWEST', 'DENVER')
# (2628, 761, 'Sunday', 'ALASKA', 'NEW YORK-JFK')
# (2630, 852, 'Tuesday', 'ALASKA', 'PORTLAND')
# (2631, 1791, 'Saturday', 'UNITED', 'RALEIGH-DURHAM')
# (2632, 1961, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (2633, 2707, 'Thursday', 'DELTA', 'LOS ANGELES')
# (2634, 375, 'Friday', 'ALASKA', 'LOS ANGELES')
# (2635, 2947, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (2636, 1172, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (2637, 2581, 'Tuesday', 'JETBLUE', 'BOSTON')
# (2638, 1312, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (2640, 827, 'Sunday', 'ALASKA', 'SEATTLE')
# (2641, 2115, 'Monday', 'UNITED INTL', 'MEXICO CITY')
# (2642, 469, 'Sunday', 'ALASKA', 'PORTLAND')
# (2643, 3272, 'Tuesday', 'UNITED', 'LAS VEGAS')
# (2644, 378, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (2646, 2407, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (2647, 1491, 'Wednesday', 'HAWAIIAN AIR', 'HONOLULU')
# (2648, 1512, 'Wednesday', 'DELTA', 'LOS ANGELES')
# (2649, 3004, 'Wednesday', 'AMERICAN', 'MIAMI')
# (2651, 212, 'Wednesday', 'AMERICAN', 'LOS ANGELES')
# (2652, 505, 'Sunday', 'ALASKA', 'PORTLAND')
# (2653, 252, 'Friday', 'AIR CANADA', 'TORONTO')
# (2654, 2804, 'Tuesday', 'SOUTHWEST', 'PHOENIX')
# (2655, 2665, 'Friday', 'UNITED', 'RALEIGH-DURHAM')
# (2656, 2093, 'Thursday', 'AMERICAN', 'PHILADELPHIA')
# (2657, 2029, 'Friday', 'BRITISH AIRWAYS', 'LONDON HEATHROW')
# (2658, 2725, 'Thursday', 'DELTA', 'LOS ANGELES')
# (2659, 3226, 'Thursday', 'ALASKA', 'PORTLAND')
# (2660, 2417, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (2661, 1382, 'Tuesday', 'UNITED INTL', 'PARIS-DE GAULLE')
# (2662, 2736, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2663, 2821, 'Thursday', 'DELTA', 'LOS ANGELES')
# (2664, 3244, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (2665, 2980, 'Thursday', 'UNITED', 'NASHVILLE')
# (2666, 2058, 'Friday', 'UNITED', 'NEWARK')
# (2667, 1463, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (2668, 2850, 'Tuesday', 'UNITED', 'SEATTLE')
# (2669, 1696, 'Sunday', 'ALASKA', 'SANTA ANA')
# (2670, 1030, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (2671, 1148, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (2672, 3008, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (2673, 1740, 'Monday', 'AIR CANADA', 'TORONTO')
# (2674, 1876, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (2675, 2933, 'Friday', 'TURKISH AIRLINES', 'ISTANBUL')
# (2676, 280, 'Thursday', 'UNITED', 'BALTIMORE')
# (2677, 434, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (2678, 1171, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (2679, 2466, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (2681, 3250, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (2682, 277, 'Thursday', 'UNITED', 'BALTIMORE')
# (2683, 2461, 'Friday', 'UNITED', 'DENVER')
# (2684, 994, 'Friday', 'LUFTHANSA', 'MUNICH')
# (2685, 1021, 'Friday', 'AIR CANADA', 'VANCOUVER')
# (2686, 1637, 'Thursday', 'KOREAN AIR', 'SEOUL')
# (2687, 1886, 'Wednesday', 'SINGAPORE AIRLINES', 'SINGAPORE')
# (2688, 290, 'Wednesday', 'SOUTHWEST', 'LOS ANGELES')
# (2689, 1552, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (2690, 2999, 'Wednesday', 'AMERICAN', 'MIAMI')
# (2691, 433, 'Sunday', 'UNITED', 'HONOLULU')
# (2692, 464, 'Sunday', 'ALASKA', 'PORTLAND')
# (2693, 2989, 'Wednesday', 'AMERICAN', 'MIAMI')
# (2694, 3080, 'Tuesday', 'UNITED', 'SPOKANE')
# (2695, 1820, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (2696, 1640, 'Saturday', 'VIRGIN ATLANTIC', 'LONDON HEATHROW')
# (2697, 1592, 'Thursday', 'SOUTHWEST', 'LOS ANGELES')
# (2698, 2801, 'Sunday', 'WOW', 'REYKJAVIK')
# (2699, 562, 'Thursday', 'EMIRATES', 'DUBAI')
# (2700, 2397, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (2701, 2734, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2702, 2763, 'Wednesday', 'CATHAY PACIFIC', 'HONG KONG')
# (2703, 1147, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (2704, 351, 'Friday', 'LUFTHANSA', 'FRANKFURT')
# (2705, 1952, 'Tuesday', 'UNITED', 'BOSTON')
# (2706, 1807, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (2707, 2332, 'Tuesday', 'DELTA', 'MINNEAPOLIS-ST. PAUL')
# (2708, 2475, 'Friday', 'UNITED', 'DENVER')
# (2709, 3189, 'Thursday', 'DELTA', 'LOS ANGELES')
# (2710, 2597, 'Tuesday', 'JETBLUE', 'BOSTON')
# (2711, 3232, 'Wednesday', 'AMERICAN', 'PHOENIX')
# (2712, 1472, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (2713, 2896, 'Thursday', 'DELTA', 'SALT LAKE CITY')
# (2714, 9, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (2715, 431, 'Sunday', 'UNITED', 'INDIANAPOLIS')
# (2716, 1346, 'Tuesday', 'UNITED INTL', 'KANSAI')
# (2717, 456, 'Sunday', 'UNITED', 'DALLAS-FT. WORTH')
# (2718, 597, 'Thursday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (2720, 3123, 'Sunday', 'ALASKA', 'NEWARK')
# (2721, 2489, 'Friday', 'UNITED', 'DENVER')
# (2723, 1250, 'Thursday', 'CHINA EASTERN', 'SHANGHAI')
# (2724, 2432, 'Wednesday', 'AIR NEW ZEALAND', 'AUCKLAND')
# (2725, 991, 'Friday', 'LUFTHANSA', 'MUNICH')
# (2726, 2291, 'Wednesday', 'QANTAS', 'SYDNEY')
# (2727, 951, 'Thursday', 'AIR CANADA', 'VANCOUVER')
# (2728, 898, 'Friday', 'AIR CANADA', 'TORONTO')
# (2729, 2538, 'Saturday', 'JETBLUE', 'BOSTON')
# (2730, 1804, 'Monday', 'UNITED INTL', 'LONDON HEATHROW')
# (2731, 2181, 'Wednesday', 'QANTAS', 'SYDNEY')
# (2732, 3257, 'Tuesday', 'UNITED', 'SAN DIEGO')
# (2733, 484, 'Sunday', 'ALASKA', 'PORTLAND')
# (2734, 3021, 'Thursday', 'ALASKA', 'SEATTLE')
# (2735, 795, 'Sunday', 'ALASKA', 'BALTIMORE')
# (2737, 865, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (2738, 2302, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (2739, 502, 'Sunday', 'ALASKA', 'PORTLAND')
# (2740, 2584, 'Tuesday', 'JETBLUE', 'BOSTON')
# (2741, 3182, 'Thursday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (2742, 1496, 'Wednesday', 'HAWAIIAN AIR', 'HONOLULU')
# (2743, 291, 'Thursday', 'UNITED', 'SAN DIEGO')
# (2744, 2185, 'Wednesday', 'QANTAS', 'SYDNEY')
# (2745, 2753, 'Thursday', 'DELTA', 'ATLANTA')
# (2746, 1435, 'Saturday', 'UNITED', 'PORTLAND')
# (2747, 602, 'Thursday', 'ALASKA', 'WASHINGTON DC-DULLES')
# (2748, 3117, 'Tuesday', 'UNITED', 'SPOKANE')
# (2749, 2447, 'Tuesday', 'JETBLUE', 'BOSTON')
# (2750, 1851, 'Sunday', 'ALASKA', 'KAHULUI')
# (2751, 1729, 'Monday', 'AIR CANADA', 'TORONTO')
# (2752, 546, 'Thursday', 'ALASKA', 'SEATTLE')
# (2753, 845, 'Tuesday', 'AMERICAN', 'DALLAS-FT. WORTH')
# (2755, 2568, 'Saturday', 'JETBLUE', 'LONG BEACH')
# (2756, 1670, 'Saturday', 'EMIRATES', 'DUBAI')
# (2757, 2773, 'Sunday', 'WOW', 'REYKJAVIK')
# (2758, 516, 'Thursday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2759, 2380, 'Wednesday', 'UNITED INTL', 'SYDNEY')
# (2760, 3215, 'Tuesday', 'UNITED', 'SANTA BARBARA')
# (2761, 1162, 'Tuesday', 'SOUTHWEST', 'LOS ANGELES')
# (2762, 2502, 'Friday', 'UNITED', "CHICAGO-O'HARE")
# (2763, 880, 'Tuesday', 'ALASKA', 'SEATTLE')
# (2764, 2525, 'Saturday', 'UNITED', 'NEWARK')
# (2765, 2638, 'Tuesday', 'JETBLUE', 'NEW YORK-JFK')
# (2766, 1950, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2767, 2543, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (2768, 1458, 'Wednesday', 'FRONTIER', 'DENVER')
# (2769, 1850, 'Wednesday', 'SOUTHWEST', 'SAN DIEGO')
# (2770, 2827, 'Tuesday', 'UNITED', 'BURBANK')
# (2771, 3208, 'Thursday', 'AMERICAN', 'LOS ANGELES')
# (2772, 1700, 'Sunday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2773, 376, 'Friday', 'ALASKA', 'SAN JOSE DEL CABO')
# (2774, 2845, 'Tuesday', 'UNITED', 'SEATTLE')
# (2775, 1969, 'Friday', 'CATHAY PACIFIC', 'HONG KONG')
# (2777, 1996, 'Tuesday', 'UNITED', 'BALTIMORE')
# (2778, 2708, 'Wednesday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2780, 1744, 'Saturday', 'CATHAY PACIFIC', 'HONG KONG')
# (2781, 2843, 'Tuesday', 'UNITED', 'SEATTLE')
# (2782, 1772, 'Thursday', 'AMERICAN', "CHICAGO-O'HARE")
# (2783, 338, 'Friday', 'ALASKA', 'SAN DIEGO')
# (2784, 366, 'Friday', 'LUFTHANSA', 'FRANKFURT')
# (2785, 1179, 'Thursday', 'DELTA', 'NEW YORK-JFK')
# (2786, 1947, 'Saturday', 'AIR FRANCE/KLM', 'PARIS-DE GAULLE')
# (2787, 1305, 'Tuesday', 'UNITED INTL', 'LONDON HEATHROW')
# (2788, 3196, 'Thursday', 'DELTA', 'LOS ANGELES')
# (2789, 976, 'Friday', 'LUFTHANSA', 'MUNICH')
# (2791, 777, 'Thursday', 'UNITED INTL', 'SAN JOSE DEL CABO')
# (2792, 2171, 'Wednesday', 'FRONTIER', 'DENVER')
# (2793, 2570, 'Tuesday', 'UNITED', "CHICAGO-O'HARE")
# (2794, 3007, 'Wednesday', 'AMERICAN', 'MIAMI')
# (2795, 820, 'Sunday', 'ALASKA', 'PORTLAND')
# (2796, 1125, 'Tuesday', 'SOUTHWEST', 'SAN DIEGO')
# (2797, 1466, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (2798, 3099, 'Sunday', 'ALASKA', 'NEWARK')
# (2799, 2399, 'Wednesday', 'UNITED INTL', 'BEIJING')
# (2800, 1942, 'Tuesday', 'UNITED', 'BOSTON')
# (2801, 2130, 'Thursday', 'CATHAY PACIFIC', 'HONG KONG')
# (2802, 394, 'Friday', 'ALASKA', 'LOS ANGELES')
# (2803, 2888, 'Wednesday', 'UNITED', 'AUSTIN')
# (2804, 1475, 'Tuesday', 'ALASKA', 'NEW YORK-JFK')
# (2805, 2222, 'Thursday', 'SOUTHWEST', 'PHOENIX')
# (2806, 2684, 'Friday', 'UNITED', 'ORLANDO')
# (2807, 2549, 'Tuesday', 'JETBLUE', 'LONG BEACH')
# (2808, 2162, 'Saturday', 'CHINA EASTERN', 'QINGDAO')
